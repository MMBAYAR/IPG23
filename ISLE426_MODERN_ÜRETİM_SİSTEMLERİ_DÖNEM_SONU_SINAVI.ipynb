# %% [markdown]
# <a href="https://colab.research.google.com/github/MMBAYAR/IPG23/blob/main/ISLE426_MODERN_%C3%9CRET%C4%B0M_S%C4%B0STEMLER%C4%B0_D%C3%96NEM_SONU_SINAVI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###<div align="right">12.06.2023<br>
# ##<div align="center">T.C.<br>
# ##<div align="center">ANKARA HACI BAYRAM VELİ ÜNİVERSİTESİ<br>
# ##<div align="center">İKİTSADİ ve İDARİ BİLİMLER FAKÜLTESİ - İŞLETME BÖLÜMÜ<br>
# ##<div align="center">ISLE426 MODERN ÜRETİM SİSTEMLERİ - DÖNEM SONU SINAVI<br><br>
#
# Bu *dönem sonu sınavı ödevinin* en geç **23.06.2023 Cuma günü saat 17.oo**'ye kadar mehmet.bayar@hbv.edu.tr adresine iletilmesi gerekmektedir.<br><br>
#
# **AÇIKLAMALAR:**<br>
# **1.** Aşağıdaki 3 soruyu dikkatle okuyunuz. Bu üç soru, üç ayrı kod hücresinde belirtilmiştir. Herbir kod hücresinde yorum satırları içerisinde belirtilmiş görevler ilgili soruyu oluşturmaktadır.<br>
# **2.** Bu üç sorudan yalnızca 1 tanesini seçiniz ve sorunun yer aldığı kod hücresi içerisinde gerekli kodu Python Programlama dilini kullanarak yazınız.<br>
# **3.** Yanıtladığınız - kodunu yazdığınız - kod hücresini çalıştırarak kod çıktısını elde ediniz. Soru içerisinde belirtilen görevlerle elde ettiğiniz kod çıktısının uyuştuğunu kontrol etmelisiniz.<br>
# **4.** Birden çok soruyu yanıtlayan bir öğrencinin ilk okunan yanıtı değerlendirilecek ve diğer yanıtları okunmayacaktır.<br>
# **5.** Sistemde ya da internet bağlantınızda yaşanabilecek aksaklıklar nedeniyle önerim, teslimi en geç **20.06.2023 Salı günü saat 23.59**'a kadar tamamlamanız, en az iki defa kontrol etmeniz ve mehmet.bayar@hbv.edu.tr adresine iletmenizdir.
# **6.** Bilger'de kabul yüklemenize izin verilen dosya türleri arasında "*.ipynb*" uzantılı dosyalar yer almadığından dönem sonu sınavı ödevlerinizi bana yalnızca e-posta ile iletebileceksiniz.

# %%
#  SORU 1:

#  "ad", "soyad" ve "öğrenci_numarası" adlarını vereceğiniz üç değişken tanımlayınız ve bu değişkenlere "None" değeri giriniz.

#  Bu değişkenlerin değerlerini; birer karakter dizisi (string) tipinde Python nesnesi olarak adınız, soyadınız ve öğrenci numaranız olarak güncelleyiniz.

#  Bu üç değişkeni print() fonksiyonunu kullanarak yazdırınız. Bu kod çıktısında adınız, soyadınız ve öğrenci numaranız arasında birer boşluk olmalıdır.
# Out:
# Mustafa Mehmet Bayar 2237200000

# %%
#  SORU 2:

#  scikit-optimize kütüphanesini Colab oturumunda kullanmakta olduğunuz bulut bilgisayara yükleyiniz.

#  skopt içerisinden BayesSearchCV yöntemini BS adını vererek oturuma çağırınız.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
#  SORU 3:

#  Aşağıdaki kod satırlarında oluşturulan fonksiyonu inceleyiniz.
def fonksiyon(x):
  from numpy import cos,sin
  sinyal = 5 - sum( ( cos(x) )**i for i in range(1,10+1) )+ sum( ( sin(x) )**i for i in range(1,10+1) )

  from numpy.random import normal as gürültü
  for i in range( len(sinyal) ):
    sinyal[i] += gürültü( loc = 0, scale = 2 )

  return sinyal
  del sinyal
#  numpy kütüphanesi içerisinden "pi"yi çağırınız

#  numpy kütüphanesi içerisinden "linspace" fonksiyonunu çağırınız

#  Yukarıda verilen fonksiyona argüman (girdi) olarak 0'dan başlayan ve 4*pi'ye kadar olan eşit aralıklı 10000 değeri içeren numpy dizisini veriniz.

#  Bir önceki adımda elde ettiğiniz değerleri y; girdi olarak verdiğiniz değerleri de x adındaki birer değişkene değerler olarak atayınız.

#  Seaborn kütüphanesi içerisinden scatterplot fonksiyonunu çağırınız

#  scatterplot fonksiyonu içerisinde parametre olarak x'i x olarak, y'yi y olarak ve matlık parametresini de 0.025 olarak tanımlayıp grafik çizdiriniz.
# Out:
# <Axes: >

# %% [markdown]
# ###<div align="right">Başarılar,<br>
# ###<div align="right">Mustafa Mehmet BAYAR<br>
